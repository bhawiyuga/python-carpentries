# %% [markdown]
# # Repeating Actions with Loops

# %% [markdown]
# ## Without loops

# %% [markdown]
# ## With loops

# %% [markdown]
# ## Looping in a list

# %% [markdown]
# ## Looping in a dictionary
