# %% [markdown]
# # Python Fundamentals

# %% [markdown]
# ## Variables

# %% [markdown]
# ## Types of data

# %% [markdown]
# ## Using Variables in Python

# %% [markdown]
# ## Built-in Python functions

# %% [markdown]
# ## Getting Help

# %% [markdown]
# ## Use of Generative AI
